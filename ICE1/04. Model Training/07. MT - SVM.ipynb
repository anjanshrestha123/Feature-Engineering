# %% [markdown]
# # Support Vector Machine

# %%
import pickle
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import svm
from pprint import pprint
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.model_selection import ShuffleSplit
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# First, we load the data:

# %%
# Dataframe
path_df = "../03. Feature Engineering/Pickles/df.pickle"
with open(path_df, 'rb') as data:
    df = pickle.load(data)

# features_train
path_features_train = "../03. Feature Engineering/Pickles/features_train.pickle"
with open(path_features_train, 'rb') as data:
    features_train = pickle.load(data)

# labels_train
path_labels_train = "../03. Feature Engineering/Pickles/labels_train.pickle"
with open(path_labels_train, 'rb') as data:
    labels_train = pickle.load(data)

# features_test
path_features_test = "../03. Feature Engineering/Pickles/features_test.pickle"
with open(path_features_test, 'rb') as data:
    features_test = pickle.load(data)

# labels_test
path_labels_test = "../03. Feature Engineering/Pickles/labels_test.pickle"
with open(path_labels_test, 'rb') as data:
    labels_test = pickle.load(data)

# %% [markdown]
# Let's check the dimension of our feature vectors:

# %%
print(features_train.shape)
print(features_test.shape)
# Out:
# (37, 173)
# (7, 173)

# %% [markdown]
# ## Cross-Validation for Hyperparameter tuning

# %% [markdown]
# First, we can see what hyperparameters the model has:

# %%
svc_0 =svm.SVC(random_state=8)

print('Parameters currently in use:\n')
pprint(svc_0.get_params())
# Out:
# Parameters currently in use:
#
# {'C': 1.0,
#  'break_ties': False,
#  'cache_size': 200,
#  'class_weight': None,
#  'coef0': 0.0,
#  'decision_function_shape': 'ovr',
#  'degree': 3,
#  'gamma': 'scale',
#  'kernel': 'rbf',
#  'max_iter': -1,
#  'probability': False,
#  'random_state': 8,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %% [markdown]
# We'll tune the following ones:
#
# * `C`: Penalty parameter C of the error term.
# * `kernel`: Specifies the kernel type to be used in the algorithm.
# * `gamma`: Kernel coefficient.
# * `degree`: Degree of the polynomial kernel function.

# %% [markdown]
# ### Randomized Search Cross Validation

# %% [markdown]
# We first need to define the grid:

# %%
# C
C = [.0001, .001, .01]

# gamma
gamma = [.0001, .001, .01, .1, 1, 10, 100]

# degree
degree = [1, 2, 3, 4, 5]

# kernel
kernel = ['linear', 'rbf', 'poly']

# probability
probability = [True]

# Create the random grid
random_grid = {'C': C,
              'kernel': kernel,
              'gamma': gamma,
              'degree': degree,
              'probability': probability
             }

pprint(random_grid)
# Out:
# {'C': [0.0001, 0.001, 0.01],
#  'degree': [1, 2, 3, 4, 5],
#  'gamma': [0.0001, 0.001, 0.01, 0.1, 1, 10, 100],
#  'kernel': ['linear', 'rbf', 'poly'],
#  'probability': [True]}

# %% [markdown]
# Then, we'll perform the Random Search:

# %%
# First create the base model to tune
svc = svm.SVC(random_state=8)

# Definition of the random search
random_search = RandomizedSearchCV(estimator=svc,
                                   param_distributions=random_grid,
                                   n_iter=50,
                                   scoring='accuracy',
                                   cv=3, 
                                   verbose=1, 
                                   random_state=8)

# Fit the random search model
random_search.fit(features_train, labels_train)
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
# ...
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py:922: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-ce56699bf93d> in <module>
#      12
#      13 # Fit the random search model
# ---> 14 random_search.fit(features_train, labels_train)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     878             refit_start_time = time.time()
#     879             if y is not None:
# --> 880                 self.best_estimator_.fit(X, y, **fit_params)
#     881             else:
#     882                 self.best_estimator_.fit(X, **fit_params)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py in fit(self, X, y, sample_weight)
#     171                                        accept_large_sparse=False)
#     172
# --> 173         y = self._validate_targets(y)
#     174
#     175         sample_weight = np.asarray([]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py in _validate_targets(self, y)
#     551     def _validate_targets(self, y):
#     552         y_ = column_or_1d(y, warn=True)
# --> 553         check_classification_targets(y)
#     554         cls, y = np.unique(y_, return_inverse=True)
#     555         self.class_weight_ = compute_class_weight(self.class_weight,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py in check_classification_targets(y)
#     181     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
#     182                       'multilabel-indicator', 'multilabel-sequences']:
# --> 183         raise ValueError("Unknown label type: %r" % y_type)
#     184
#     185
#
# ValueError: Unknown label type: 'unknown'

# %% [markdown]
# We can see the best hyperparameters resulting from the Random Search:

# %%
print("The best hyperparameters from Random Search are:")
print(random_search.best_params_)
print("")
print("The mean accuracy of a model with these hyperparameters is:")
print(random_search.best_score_)
# Out:
# The best hyperparameters from Random Search are:
# {'probability': True, 'kernel': 'poly', 'gamma': 0.001, 'degree': 4, 'C': 0.01}
#
# The mean accuracy of a model with these hyperparameters is:
# nan

# %% [markdown]
# After that, we can do a more exhaustive search centered in those values:

# %% [markdown]
# ### Grid Search Cross Validation

# %%
# Create the parameter grid based on the results of random search 
C = [.0001, .001, .01, .1]
degree = [3, 4, 5]
gamma = [1, 10, 100]
probability = [True]

param_grid = [
  {'C': C, 'kernel':['linear'], 'probability':probability},
  {'C': C, 'kernel':['poly'], 'degree':degree, 'probability':probability},
  {'C': C, 'kernel':['rbf'], 'gamma':gamma, 'probability':probability}
]

# Create a base model
svc = svm.SVC(random_state=8)

# Manually create the splits in CV in order to be able to fix a random_state (GridSearchCV doesn't have that argument)
cv_sets = ShuffleSplit(n_splits = 3, test_size = .33, random_state = 8)

# Instantiate the grid search model
grid_search = GridSearchCV(estimator=svc, 
                           param_grid=param_grid,
                           scoring='accuracy',
                           cv=cv_sets,
                           verbose=1)

# Fit the grid search to the data
grid_search.fit(features_train, labels_train)
# Out:
# Fitting 3 folds for each of 28 candidates, totalling 84 fits
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
# ...
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "/Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'unknown'
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# /Users/aj/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py:922: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-b352076543d7> in <module>
#      25
#      26 # Fit the grid search to the data
# ---> 27 grid_search.fit(features_train, labels_train)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     878             refit_start_time = time.time()
#     879             if y is not None:
# --> 880                 self.best_estimator_.fit(X, y, **fit_params)
#     881             else:
#     882                 self.best_estimator_.fit(X, **fit_params)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py in fit(self, X, y, sample_weight)
#     171                                        accept_large_sparse=False)
#     172
# --> 173         y = self._validate_targets(y)
#     174
#     175         sample_weight = np.asarray([]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py in _validate_targets(self, y)
#     551     def _validate_targets(self, y):
#     552         y_ = column_or_1d(y, warn=True)
# --> 553         check_classification_targets(y)
#     554         cls, y = np.unique(y_, return_inverse=True)
#     555         self.class_weight_ = compute_class_weight(self.class_weight,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py in check_classification_targets(y)
#     181     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
#     182                       'multilabel-indicator', 'multilabel-sequences']:
# --> 183         raise ValueError("Unknown label type: %r" % y_type)
#     184
#     185
#
# ValueError: Unknown label type: 'unknown'

# %% [markdown]
# The best hyperparameters turn out to be:

# %%
print("The best hyperparameters from Grid Search are:")
print(grid_search.best_params_)
print("")
print("The mean accuracy of a model with these hyperparameters is:")
print(grid_search.best_score_)
# Out:
# The best hyperparameters from Grid Search are:
# {'C': 0.0001, 'kernel': 'linear', 'probability': True}
#
# The mean accuracy of a model with these hyperparameters is:
# nan

# %% [markdown]
# Let's save the model in `best_svc`:

# %%
best_svc = grid_search.best_estimator_

# %%
best_svc
# Out:
# SVC(C=0.0001, kernel='linear', probability=True, random_state=8)

# %% [markdown]
# We now know the best SVM model. Let's fit it and see how it performs:

# %% [markdown]
# ## Model fit and performance

# %% [markdown]
# Now, we can fit the model to our training data:

# %%
best_svc.fit(features_train, labels_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-5d00349c5914> in <module>
# ----> 1 best_svc.fit(features_train, labels_train)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py in fit(self, X, y, sample_weight)
#     171                                        accept_large_sparse=False)
#     172
# --> 173         y = self._validate_targets(y)
#     174
#     175         sample_weight = np.asarray([]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py in _validate_targets(self, y)
#     551     def _validate_targets(self, y):
#     552         y_ = column_or_1d(y, warn=True)
# --> 553         check_classification_targets(y)
#     554         cls, y = np.unique(y_, return_inverse=True)
#     555         self.class_weight_ = compute_class_weight(self.class_weight,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py in check_classification_targets(y)
#     181     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
#     182                       'multilabel-indicator', 'multilabel-sequences']:
# --> 183         raise ValueError("Unknown label type: %r" % y_type)
#     184
#     185
#
# ValueError: Unknown label type: 'unknown'

# %% [markdown]
# And get the predictions:

# %%
svc_pred = best_svc.predict(features_test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-b3fd9729d874> in <module>
# ----> 1 svc_pred = best_svc.predict(features_test)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py in predict(self, X)
#     622             y = np.argmax(self.decision_function(X), axis=1)
#     623         else:
# --> 624             y = super().predict(X)
#     625         return self.classes_.take(np.asarray(y, dtype=np.intp))
#     626
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py in predict(self, X)
#     340         y_pred : ndarray of shape (n_samples,)
#     341         """
# --> 342         X = self._validate_for_predict(X)
#     343         predict = self._sparse_predict if self._sparse else self._dense_predict
#     344         return predict(X)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py in _validate_for_predict(self, X)
#     490                                  "the number of samples at training time" %
#     491                                  (X.shape[1], self.shape_fit_[0]))
# --> 492         elif not callable(self.kernel) and X.shape[1] != self.shape_fit_[1]:
#     493             raise ValueError("X.shape[1] = %d should be equal to %d, "
#     494                              "the number of features at training time" %
#
# AttributeError: 'SVC' object has no attribute 'shape_fit_'

# %% [markdown]
# The conditional class probabilities can be obtained by typing:
#
# `svc_pred = best_svc.predict_proba(features_test)`

# %% [markdown]
# For performance analysis, we will use the confusion matrix, the classification report and the accuracy on both training and test data:

# %% [markdown]
# #### Training accuracy

# %%
# Training accuracy
print("The training accuracy is: ")
print(accuracy_score(labels_train, best_svc.predict(features_train)))
# Out:
# The training accuracy is:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-e3d9e11ecc64> in <module>
#       1 # Training accuracy
#       2 print("The training accuracy is: ")
# ----> 3 print(accuracy_score(labels_train, best_svc.predict(features_train)))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py in predict(self, X)
#     622             y = np.argmax(self.decision_function(X), axis=1)
#     623         else:
# --> 624             y = super().predict(X)
#     625         return self.classes_.take(np.asarray(y, dtype=np.intp))
#     626
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py in predict(self, X)
#     340         y_pred : ndarray of shape (n_samples,)
#     341         """
# --> 342         X = self._validate_for_predict(X)
#     343         predict = self._sparse_predict if self._sparse else self._dense_predict
#     344         return predict(X)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py in _validate_for_predict(self, X)
#     490                                  "the number of samples at training time" %
#     491                                  (X.shape[1], self.shape_fit_[0]))
# --> 492         elif not callable(self.kernel) and X.shape[1] != self.shape_fit_[1]:
#     493             raise ValueError("X.shape[1] = %d should be equal to %d, "
#     494                              "the number of features at training time" %
#
# AttributeError: 'SVC' object has no attribute 'shape_fit_'

# %% [markdown]
# #### Test accuracy

# %%
# Test accuracy
print("The test accuracy is: ")
print(accuracy_score(labels_test, svc_pred))
# Out:
# The test accuracy is:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-d94916d5254d> in <module>
#       1 # Test accuracy
#       2 print("The test accuracy is: ")
# ----> 3 print(accuracy_score(labels_test, svc_pred))
#
# NameError: name 'svc_pred' is not defined

# %% [markdown]
# #### Classification report

# %%
# Classification report
print("Classification report")
print(classification_report(labels_test,svc_pred))
# Out:
# Classification report
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-76ac4b3ce0a6> in <module>
#       1 # Classification report
#       2 print("Classification report")
# ----> 3 print(classification_report(labels_test,svc_pred))
#
# NameError: name 'svc_pred' is not defined

# %% [markdown]
# #### Confusion matrix

# %%
aux_df = df[['Category', 'Category_Code']].drop_duplicates().sort_values('Category_Code')
conf_matrix = confusion_matrix(labels_test, svc_pred)
plt.figure(figsize=(12.8,6))
sns.heatmap(conf_matrix, 
            annot=True,
            xticklabels=aux_df['Category'].values, 
            yticklabels=aux_df['Category'].values,
            cmap="Blues")
plt.ylabel('Predicted')
plt.xlabel('Actual')
plt.title('Confusion matrix')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-c734e4be77f3> in <module>
# ----> 1 aux_df = df[['Category', 'Category_Code']].drop_duplicates().sort_values('Category_Code')
#       2 conf_matrix = confusion_matrix(labels_test, svc_pred)
#       3 plt.figure(figsize=(12.8,6))
#       4 sns.heatmap(conf_matrix,
#       5             annot=True,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    5462                 ascending = ascending[0]
#    5463
# -> 5464             indexer = nargsort(
#    5465                 k, kind=kind, ascending=ascending, na_position=na_position, key=key
#    5466             )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/sorting.py in nargsort(items, kind, ascending, na_position, key, mask)
#     378         non_nans = non_nans[::-1]
#     379         non_nan_idx = non_nan_idx[::-1]
# --> 380     indexer = non_nan_idx[non_nans.argsort(kind=kind)]
#     381     if not ascending:
#     382         indexer = indexer[::-1]
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %% [markdown]
# At this point, we could get the average time the model takes to get predictions. We want the algorithm to be fast since we are creating an app which will gather data from the internet and get the predicted categories. However, since the difference when predicting 10-20 observations will be very little, we won't take this into account.
#
# However, the code below could do this task:
#
# ```python
# features_time = features_train
# elapsed_list = []
# for i in range(0,10):
#
#     start = time.time()
#     predictions = best_lrc.predict(features_time)
#     end = time.time()
#     elapsed = end - start
#     elapsed_list.append(elapsed)
#
# mean_time_elapsed = np.mean(elapsed_list)
# ```

# %% [markdown]
# Let's see if the hyperparameter tuning process has returned a better model:

# %%
base_model = svm.SVC(random_state = 8)
base_model.fit(features_train, labels_train)
accuracy_score(labels_test, base_model.predict(features_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-dc8fcf60a925> in <module>
#       1 base_model = svm.SVC(random_state = 8)
# ----> 2 base_model.fit(features_train, labels_train)
#       3 accuracy_score(labels_test, base_model.predict(features_test))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py in fit(self, X, y, sample_weight)
#     171                                        accept_large_sparse=False)
#     172
# --> 173         y = self._validate_targets(y)
#     174
#     175         sample_weight = np.asarray([]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py in _validate_targets(self, y)
#     551     def _validate_targets(self, y):
#     552         y_ = column_or_1d(y, warn=True)
# --> 553         check_classification_targets(y)
#     554         cls, y = np.unique(y_, return_inverse=True)
#     555         self.class_weight_ = compute_class_weight(self.class_weight,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py in check_classification_targets(y)
#     181     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
#     182                       'multilabel-indicator', 'multilabel-sequences']:
# --> 183         raise ValueError("Unknown label type: %r" % y_type)
#     184
#     185
#
# ValueError: Unknown label type: 'unknown'

# %%
best_svc.fit(features_train, labels_train)
accuracy_score(labels_test, best_svc.predict(features_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-5581aada4f1e> in <module>
# ----> 1 best_svc.fit(features_train, labels_train)
#       2 accuracy_score(labels_test, best_svc.predict(features_test))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py in fit(self, X, y, sample_weight)
#     171                                        accept_large_sparse=False)
#     172
# --> 173         y = self._validate_targets(y)
#     174
#     175         sample_weight = np.asarray([]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py in _validate_targets(self, y)
#     551     def _validate_targets(self, y):
#     552         y_ = column_or_1d(y, warn=True)
# --> 553         check_classification_targets(y)
#     554         cls, y = np.unique(y_, return_inverse=True)
#     555         self.class_weight_ = compute_class_weight(self.class_weight,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py in check_classification_targets(y)
#     181     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
#     182                       'multilabel-indicator', 'multilabel-sequences']:
# --> 183         raise ValueError("Unknown label type: %r" % y_type)
#     184
#     185
#
# ValueError: Unknown label type: 'unknown'

# %% [markdown]
# We'll create a dataset with a model summary to compare models:

# %%
d = {
     'Model': 'SVM',
     'Training Set Accuracy': accuracy_score(labels_train, best_svc.predict(features_train)),
     'Test Set Accuracy': accuracy_score(labels_test, svc_pred)
}

df_models_svc = pd.DataFrame(d, index=[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-efb09e4f3989> in <module>
#       1 d = {
#       2      'Model': 'SVM',
# ----> 3      'Training Set Accuracy': accuracy_score(labels_train, best_svc.predict(features_train)),
#       4      'Test Set Accuracy': accuracy_score(labels_test, svc_pred)
#       5 }
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py in predict(self, X)
#     622             y = np.argmax(self.decision_function(X), axis=1)
#     623         else:
# --> 624             y = super().predict(X)
#     625         return self.classes_.take(np.asarray(y, dtype=np.intp))
#     626
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py in predict(self, X)
#     340         y_pred : ndarray of shape (n_samples,)
#     341         """
# --> 342         X = self._validate_for_predict(X)
#     343         predict = self._sparse_predict if self._sparse else self._dense_predict
#     344         return predict(X)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py in _validate_for_predict(self, X)
#     490                                  "the number of samples at training time" %
#     491                                  (X.shape[1], self.shape_fit_[0]))
# --> 492         elif not callable(self.kernel) and X.shape[1] != self.shape_fit_[1]:
#     493             raise ValueError("X.shape[1] = %d should be equal to %d, "
#     494                              "the number of features at training time" %
#
# AttributeError: 'SVC' object has no attribute 'shape_fit_'

# %%
df_models_svc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-4e5d9fa17151> in <module>
# ----> 1 df_models_svc
#
# NameError: name 'df_models_svc' is not defined

# %% [markdown]
# Let's save the model and this dataset:

# %%
with open('Models/best_svc.pickle', 'wb') as output:
    pickle.dump(best_svc, output)
    
with open('Models/df_models_svc.pickle', 'wb') as output:
    pickle.dump(df_models_svc, output)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-54466b1ebe6f> in <module>
#       3
#       4 with open('Models/df_models_svc.pickle', 'wb') as output:
# ----> 5     pickle.dump(df_models_svc, output)
#
# NameError: name 'df_models_svc' is not defined
